# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
moy = 0.001512
x = np.linspace(0,0.02,200)
def distrib(x):
    return 1 / (np.exp(-(x-moy)*200) + 1)
plt.plot(x,distrib(x))

# %%
distrib(0.01)
# Out:
# 0.845221021116694
